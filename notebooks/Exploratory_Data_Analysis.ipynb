# %%
import pandas as pd

# Ruta al archivo de datos procesados
processed_data_path = "../data/processed/test_FD001_processed.csv"

# Cargar los datos
df = pd.read_csv(processed_data_path)
df.head()
# Out:
#          0         1         2         3    4    5         6         7  \
# 0 -1.78674 -1.429375  1.049295  1.005927  0.0  0.0  1.359276 -0.561495
# 1 -1.78674 -1.410527 -1.220748 -1.034755  0.0  0.0 -1.908502  0.070116
# 2 -1.78674 -1.391679  0.141278  0.325700  0.0  0.0 -0.037636 -0.231698
# 3 -1.78674 -1.372830  1.911912 -0.014414  0.0  0.0 -0.087526 -0.795350
# 4 -1.78674 -1.353982  0.640688 -0.014414  0.0  0.0  0.087088 -0.181729
#
#           8             9  ...        16        17        18        19  \
# 0 -0.975674 -1.776357e-15  ... -0.049542 -0.720590 -1.315031 -0.711659
# 1 -1.392836 -1.776357e-15  ...  0.736727 -0.193647  0.065977 -1.570037
# 2 -0.507676 -1.776357e-15  ...  0.397202 -0.720590 -0.868436  0.629340
# 3  0.251888 -1.776357e-15  ... -0.657113 -0.369295 -0.593609 -1.177045
# 4 -0.420954 -1.776357e-15  ...  0.718857 -0.720590 -0.923402 -0.784053
#
#              20        21   22   23        24        25
# ...

# %%
# Descripción estadística básica
df.describe()

# Visualizar la distribución de las características
import seaborn as sns
import matplotlib.pyplot as plt

# Histograma de todas las columnas
df.hist(bins=50, figsize=(20,15))
plt.show()

# Matriz de correlación
corr_matrix = df.corr()
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", linewidths=0.5)
plt.show()

# %%
import matplotlib.pyplot as plt

# Seleccionar algunas columnas de interés para visualizar
columns_of_interest = [0, 1, 2, 3, 4]  # Cambia los números a las columnas que te interesen
for col in columns_of_interest:
    plt.plot(df.index, df.iloc[:, col], label=f'Feature {col}')

plt.xlabel("Cycle (Index)")
plt.ylabel("Sensor Readings")
plt.title("Sensor Readings Over Cycles")
plt.legend()
plt.show()

# %%
# Supongamos que cada secuencia tiene N ciclos
N = 100  # Número de ciclos (esto es un ejemplo, ajústalo según tus datos)

# Crear una lista de secuencias
sequences = [df.iloc[i:i+N] for i in range(0, len(df), N)]

# Visualizar la primera secuencia
sequence = sequences[0]  # Elegir la primera secuencia
for col in columns_of_interest:
    plt.plot(sequence.index, sequence.iloc[:, col], label=f'Feature {col}')

plt.xlabel("Cycle (Index)")
plt.ylabel("Sensor Readings")
plt.title("Sensor Readings Over Cycles for First Sequence")
plt.legend()
plt.show()
